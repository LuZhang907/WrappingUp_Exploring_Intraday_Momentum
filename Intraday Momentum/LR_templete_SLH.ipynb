# %%
import pandas as pd
import numpy as np
import statsmodels.regression.linear_model as sm

# %% [markdown]
# ### Linear Regression

# %%
returns = pd.read_csv("/Users/luzhang/Documents/GitHub/WrappingUp_Exploring_Intraday_Momentum_2rd_try/Data/AMZN_nscoreReturns.csv")

# %%
returns
# Out:
#           R_LH     R_LH0     R_ROD      R_ON      R_FH    R_ONFH       R_M  \
# 0     2.023350 -1.718397  0.068024 -0.484457 -0.647212 -0.815781  0.939555
# 1    -0.634289  2.023350 -0.799979 -0.888935 -0.150100 -0.737511 -0.439565
# 2     0.337382 -0.634289  0.867014 -0.329963  0.059236 -0.138579  1.316836
# 3     1.424493  0.335525  0.693328  0.400289  1.670495  1.444119 -0.685542
# 4    -1.485132  1.424493 -1.741902 -1.525992  0.632145 -0.855576 -1.706991
# ...        ...       ...       ...       ...       ...       ...       ...
# 2853  0.839249 -1.466885 -2.547598 -2.650067  0.405045 -2.570781 -1.079722
# 2854  2.202334  0.836757 -2.431282  1.493106 -1.636096 -0.183006 -3.029540
# 2855  1.606712  2.202334 -0.802397 -2.233100  2.621773  0.068903 -1.375426
# 2856 -1.517616  1.606712  2.037125  2.058542  1.766412  2.340766  0.712416
# 2857  0.512262 -1.517616  1.814316  1.590969 -0.977036  0.647212  2.065895
#
#          R_SLH
# 0    -0.495335
# 1    -0.442465
# 2    -0.252170
# ...

# %%
y = returns.R_SLH

# %%
X = returns[["R_LH0","R_ON","R_FH","R_ONFH","R_M"]]

# %%
lr_full = sm.OLS(y,X).fit()

# %%
lr_full.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                  R_SLH   R-squared (uncentered):                   0.004
# Model:                            OLS   Adj. R-squared (uncentered):              0.002
# Method:                 Least Squares   F-statistic:                              2.378
# Date:                Mon, 09 Oct 2023   Prob (F-statistic):                      0.0366
# Time:                        09:36:55   Log-Likelihood:                         -4048.7
# No. Observations:                2858   AIC:                                      8107.
# Df Residuals:                    2853   BIC:                                      8137.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...
