# %%
import pandas as pd
import numpy as np
import statsmodels.regression.linear_model as sm
from sklearn.preprocessing import PolynomialFeatures

# %% [markdown]
# ### Linear Regression

# %%
returns = pd.read_csv("/Users/luzhang/Documents/GitHub/WrappingUp_Exploring_Intraday_Momentum_2rd_try/Data/AAPL_nscoreReturns.csv")

# %%
returns
# Out:
#           R_LH     R_LH0     R_ROD      R_ON      R_FH    R_ONFH       R_M  \
# 0    -0.413449 -0.419141  1.184093  0.935499 -0.527198  0.668766  0.993688
# 1    -0.978128 -0.413449  0.155494 -0.061813 -0.771396 -0.431523  0.547301
# 2    -0.117729 -0.979533 -0.058327 -0.635404  0.062685 -0.552361  0.770225
# 3    -1.414425 -0.117729 -0.688483  0.291181 -0.891912 -0.188166 -0.564563
# 4     0.764386 -1.416795  0.094105  0.378629 -0.825244 -0.060070  0.480765
# ...        ...       ...       ...       ...       ...       ...       ...
# 2876  0.078385 -1.585697 -1.660363 -2.013311  0.036550 -1.963091 -1.025553
# 2877  1.733779  0.078385 -1.234710  2.000277  0.347957  1.939731 -2.084223
# 2878  1.251668  1.729881  1.357595 -0.212134  2.528523  1.749640 -0.574797
# 2879 -1.875363  1.249766  1.685034  1.726009  1.329701  1.951278  0.920775
# 2880  0.550335 -1.880437  1.105360  0.714073 -0.566605  0.403046  1.234710
#
#          R_SLH
# 0     0.964185
# 1     0.223716
# 2    -0.919447
# ...

# %%
y = returns.R_FH

# %%
X = returns[["R_LH0","R_ON"]]

# %%
lr_full = sm.OLS(y,X).fit()

# %%
lr_full.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                   R_FH   R-squared (uncentered):                   0.006
# Model:                            OLS   Adj. R-squared (uncentered):              0.006
# Method:                 Least Squares   F-statistic:                              9.027
# Date:                Fri, 06 Oct 2023   Prob (F-statistic):                    0.000124
# Time:                        16:19:05   Log-Likelihood:                         -4078.3
# No. Observations:                2881   AIC:                                      8161.
# Df Residuals:                    2879   BIC:                                      8173.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...
