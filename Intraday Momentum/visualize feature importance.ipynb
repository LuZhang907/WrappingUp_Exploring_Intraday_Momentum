# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
feat_df = pd.read_csv("/Users/luzhang/Documents/GitHub/WrappingUp_Exploring_Intraday_Momentum/Data/final_input_features_importance.csv")

# %%
feat_df
# Out:
#                         feature  importance
# 0                 R_ROD_MAD_LH0     0.08508
# 1                       BBB_ROD     0.05263
# 2       MACDh_ROD_MACD_diff_LH0     0.05183
# 3               R_LH0_MACDh_ROD     0.04001
# 4                     MACDh_ROD     0.03430
# 5                         R_ROD     0.02912
# 6                       MOM_LH0     0.02425
# 7                    BBB_LH0_AZ     0.02154
# 8                       BBB_LH0     0.02143
# 9                    BBB_ROD_AZ     0.02129
# 10               R_FH_MACDh_LH0     0.02029
# 11        MAD_LH0_MACD_diff_ROD     0.01792
# 12            R_ROD_A_BBB_LH0_A     0.01717
# 13                        R_LH0     0.01659
# 14                       RV_LH0     0.01573
# 15          R_LH0_MACD_diff_LH0     0.01530
# 16                     RV_LH0_G     0.01394
# 17                     MACD_LH0     0.01393
# 18                 MACDh_LH0_AZ     0.01378
# 19             R_LH0_AZ_R_FH_AZ     0.01265
# ...

# %%
values = feat_df.importance    
idx = feat_df.feature
plt.figure(figsize=(18,8))
clrs = ['#2C55A0' if (x < max(values)) else '#D4AA00' for x in values ]
sns.barplot(y=idx,x=values,palette=clrs).set(title='Important features to predict last half hour return of SPY')
plt.savefig("/Users/luzhang/Documents/GitHub/WrappingUp_Exploring_Intraday_Momentum/Output Results/Fig3_3_fea_importance.pdf")
plt.show()
