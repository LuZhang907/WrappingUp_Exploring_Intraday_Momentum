# %%
import pandas as pd
import numpy as np
import statsmodels.regression.linear_model as sm

# %% [markdown]
# ### Linear Regression

# %%
returns = pd.read_csv("/Users/luzhang/Documents/GitHub/WrappingUp_Exploring_Intraday_Momentum_2rd_try/Data/AAPL_nscoreReturns.csv")

# %%
returns
# Out:
#           R_LH     R_LH0     R_ROD      R_ON      R_FH    R_ONFH       R_M  \
# 0     1.509765  1.246419 -0.528607  0.244302 -0.738505 -0.299307  0.537494
# 1    -2.333769  1.509765 -2.618074 -1.824671 -0.165549 -1.639472 -2.396952
# 2     2.380247 -2.333769 -1.673675  0.884561  1.328055  1.432976 -2.471457
# 3    -2.492425  2.380247 -1.142216  1.537451 -0.978250  0.722148 -0.495643
# 4     3.000963 -2.492425  1.223691  0.053994  1.628487  1.174257  0.387241
# ...        ...       ...       ...       ...       ...       ...       ...
# 2596 -0.317499  0.831638 -0.111055  0.104270 -1.366261 -0.907598  0.645433
# 2597 -0.275203 -0.319527  0.143117 -0.139224  0.202798  0.025059  0.077174
# 2598  1.095366 -0.278207 -0.626557 -0.885987  0.519762 -0.343965 -0.698582
# 2599  0.543070  1.091861 -0.342943 -0.342943 -0.498915 -0.574615  0.291254
# 2600 -0.709695  0.540837 -0.181202 -0.375840  0.216591 -0.128527 -0.210675
#
#          R_SLH
# 0    -2.042136
# 1    -1.937600
# 2    -1.540600
# 3    -3.101976
# 4     1.474561
# ...        ...
# 2596  0.509859
# 2597  0.274202
# 2598  0.370674
# 2599 -0.663340
# 2600 -0.004819
#
# [2601 rows x 8 columns]

# %%
y = returns.R_M

# %%
X = returns[["R_LH0","R_ON","R_FH","R_ONFH"]]

# %%
lr_full = sm.OLS(y,X).fit()

# %%
lr_full.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                    R_M   R-squared (uncentered):                   0.008
# Model:                            OLS   Adj. R-squared (uncentered):              0.007
# Method:                 Least Squares   F-statistic:                              6.066
# Date:                Fri, 06 Oct 2023   Prob (F-statistic):                    7.39e-05
# Time:                        16:41:56   Log-Likelihood:                         -4065.3
# No. Observations:                2874   AIC:                                      8139.
# Df Residuals:                    2870   BIC:                                      8162.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# R_LH0          0.0005      0.019      0.027      0.979      -0.036       0.037
# R_ON           0.1478      0.081      1.831      0.067      -0.010       0.306
# R_FH           0.1302      0.053      2.454      0.014       0.026       0.234
# R_ONFH        -0.1045      0.091     -1.148      0.251      -0.283       0.074
# ==============================================================================
# Omnibus:                        0.782   Durbin-Watson:                   2.040
# Prob(Omnibus):                  0.676   Jarque-Bera (JB):                0.710
# Skew:                           0.021   Prob(JB):                        0.701
# Kurtosis:                       3.064   Cond. No.                         9.72
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
